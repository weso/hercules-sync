# %% [markdown]
# # Benchmarks
# In this notebook we will try to identify the potential bottlenecks of the synchronization system, and show a series of benchmarks with different RDF datasets.

# %% [markdown]
# ## Setup

# %% [markdown]
# As always, we will begin by adding the hercules_sync library to our path, and setting up the logging system.

# %%
import logging
import os
import sys

# set up module paths for imports
module_path = os.path.abspath(os.path.join('..'))
hercules_sync_path = os.path.abspath(os.path.join('..', 'hercules_sync'))
sys.path.append(module_path)
sys.path.append(hercules_sync_path)

# start logging system and set logging level
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logging.info("Starting logger")
# Out:
# INFO:root:Starting logger

# %% [markdown]
# ## Datasets used

# %% [markdown]
# In order to execute our benchmarks we are going to use two different datasets:
# * Real dataset: A DBpedia dataset with information about different people is going to be used to represent the performance of our system with a real dataset.
# * Synthetic dataset: We are also going to use the Berlin SPARQL Benchmark tool to generate datasets of different sizes and observe the performance of our system as the size of the data to be synchronized increases.

# %% [markdown]
# We will begin by defining a set of functions that can be used to download the dbpedia dataset and obtain a subset of it:

# %%
import bz2
import urllib.request

def read_zipped_dataset(url, decompressor=bz2):
    response = urllib.request.urlopen(url)
    content = bz2.decompress(response.read())
    return content

def get_first_lines(string, num_lines):
    return b'\n'.join(string.split(b'\n')[:num_lines])

# %% [markdown]
# Now, we will use the functions defined above to load the person data from DBpedia. Three different datasets will be stored:
# * dbpedia_dataset will contain the complete dataset
# * dbpedia_dataset_preview will contain just the first 100 lines of the dataset. This subset will be used first to identify potential bottlenecks of the system.
# * dbpedia_dataset_final will contain the first 4000 lines of the dataset. This subset will be used later on for our benchmarks will real data.

# %%
DBPEDIA_PERSONDATA_URL = 'http://downloads.dbpedia.org/3.4/en/persondata_en.nt.bz2'
NUM_TRIPLES_FINAL = 4000
NUM_TRIPLES_PREVIEW = 100

dbpedia_dataset = read_zipped_dataset(DBPEDIA_PERSONDATA_URL, bz2)
dbpedia_dataset_preview = get_first_lines(dbpedia_dataset, NUM_TRIPLES_PREVIEW)
dbpedia_dataset_final = get_first_lines(dbpedia_dataset, NUM_TRIPLES_FINAL)

# %% [markdown]
# Now, we will proceed to create the synthetic datasets. We will first create a function that calls the BSBM tool to generate a synthetic dataset with the given number of products:

# %% [markdown]
# ## Analysing bottlenecks of the application

# %% [markdown]
# In this section we are going to execute an initial dump of the DBpedia preview dataset to identify which are the parts of the synchronization that take the most amount of time to execute. First of all, we are going to define the algorithm to use, and to reset the URIs factory to an initial state:

# %%
from hercules_sync.external.uri_factory_mock import URIFactory
from hercules_sync.git import GitFile
from hercules_sync.synchronization import GraphDiffSyncAlgorithm, OntologySynchronizer

algorithm = GraphDiffSyncAlgorithm()
synchronizer = OntologySynchronizer(algorithm)
factory = URIFactory()
factory.reset_factory()

# %% [markdown]
# Noew, we will define a function to completely reset the state of the Wikibase instance. Since we are going to make several dumps of data to the Wikibase in this notebook, it is important to reset its state before adding more data. In this case we are connecting to the machine where the Wikibase is running (in docker containers), and calling a script that resets the docker volumes:

# %%
import paramiko

from hercules_sync.triplestore import WikibaseAdapter
from secret import SSH_USER, SSH_PASS, USERNAME, PASSWORD

wikibase_host = '156.35.94.149'
ssh_port = '22'
mediawiki_api_url = f'http://{wikibase_host}:8181/w/api.php'
sparql_endpoint_url = f'http://{wikibase_host}:8282/proxy/wdqs/bigdata/namespace/wdq/sparql'
adapter = WikibaseAdapter(mediawiki_api_url, sparql_endpoint_url, USERNAME, PASSWORD)

def reset_wb_state(factory):
    global adapter
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect(wikibase_host, ssh_port, SSH_USER, SSH_PASS)
    stdin, stdout, stderr = ssh.exec_command('cd wikibase-docker && sh clean_restart.sh')
    factory.reset_factory()
    adapter = WikibaseAdapter(mediawiki_api_url, sparql_endpoint_url, USERNAME, PASSWORD)
# Out:
# http://156.35.94.149:8181/w/api.php
# INFO:hercules_sync.triplestore.wikibase_adapter:Mappings property was not found in the wikibase. Creating it...
# Successfully logged in as WikibaseAdmin
# /Users/laika/.envs/weso/lib/python3.7/site-packages/wikidataintegrator/wdi_core.py:218: UserWarning: Warning: No distinct value properties found
# Please set P2302 and Q21502410 in your wikibase or set `core_props` manually.
# Continuing with no core_props
#   "Please set P2302 and Q21502410 in your wikibase or set `core_props` manually.\n" +
# /Users/laika/.envs/weso/lib/python3.7/site-packages/wikidataintegrator/wdi_core.py:175: UserWarning: mapping relation types are being ignored
#   warnings.warn("mapping relation types are being ignored")
# INFO:hercules_sync.triplestore.wikibase_adapter:Mappings property has been created: P1

# %%
def execute_synchronization(source_content, target_content, synchronizer, adapter):
    gitfile = GitFile(None, source_content, target_content)
    ops = synchronizer.synchronize(gitfile)
    for op in ops:
        res = op.execute(adapter)
        if not res.successful:
            print(f"Error synchronizing triple: {res.message}")

# %%
import cProfile

#reset_wb_state(factory)
cProfile.run('execute_synchronization("", dbpedia_dataset_preview, synchronizer, adapter)')
# Out:
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Abel_Streight - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Perlis - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Perlis - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aaron_Sprinkle - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Aaron Sprinkle - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/A._J._Carlson - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Carlson - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Tomkins - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aaron_Temkin_Beck - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Beck - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Akira_Toriyama - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Akira - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Ahmed_Hassan_al-Bakr - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Ahmed Hassan al- Bakr - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aaron_O%27Brien - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Aaron - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Van_Vlierberghe - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Albert - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Addie_McPhail - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Addie McPhail - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Abdurrahman_Wahid - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Abdurrahman - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adrian_Hoven - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Adrian - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Fitzgerald_%28satirist%29 - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Fitzgerald - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Mitchell - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alan F. - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alben_W._Barkley - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alben W. - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adolphus_H._Tanner - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Adolphus Hitchcock - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Ace_Parker - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Clarence Parker - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Piddington - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aino_Kinjo - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Aino Kinjo - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adam_Beattie - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Adam - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aaron_Gagnon - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Aaron Gagnon - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Francis_Hegenberger - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Albert Francis Hegenberger - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adam_Smith_%28ice_hockey%29 - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Smith - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Dale - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Bennett - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alan - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alastair_Brennan - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alastair - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/A._J._Chegwidden - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: A.J. - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Akina_Minami - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Akina Minami - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Guth - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alan Harvey - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/A._Hunter_Dupree - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: A. Hunter - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_D._Sturtevant - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Albert D. Sturtevant - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aaron_Bancroft - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_J._Heeger - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alan Jay - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adam_J._Slemmer - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Adam J. - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adrian_Monck - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Monck - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adam_Gottlob_Oehlenschl%C3%A4ger - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Oehlenschläger - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/
Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Vasilevsky - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alex_MacDonald - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alex - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aaron_Lemonick - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Lemonick - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aaron_Peirsol - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Peirsol - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adrian_Kantrowitz - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Adrian - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adolf_Eugen_Fick - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Fick - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alessandro_Calori - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Calori - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alex_Arrowsmith - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Arrowsmith - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albin_Zollinger - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Zollinger - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Scott_Crossfield - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Albert Scott Crossfield - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Abimael_Youngs_Nicoll - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Abimael Youngs - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Pyun - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Albert - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Rowe - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Albert Edward - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Bourlon - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Albert - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alain_Provost - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Aleksandr_Bakulev - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Aleksandr - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Neil_Bloch - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Alan Neil - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adam_Crosthwaite - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Adam Crosthwaite - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Alphonso_Ridge - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Abigail_Garner - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Garner - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adrian_Warburton - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alain_Masudi - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/A._A._Milne - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Coady_Wedemeyer - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Wedemeyer - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Ailsa_Piper - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Ailsa - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alan_Ashton_%28Australian_politician%29 - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Alan John Ashton - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Wendt - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alanna_Kraus - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Kraus - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Alex_Bunbury - Type: item - URIElement: http://www.w3.org/1999/02/22-rdf-syntax-ns#type - Type: item - URIElement: http://xmlns.com/foaf/0.1/Person - Type: item
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Abe_Lemons - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Lemons - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Albert_Wheeler_Coffrin - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Albert Wheeler Coffrin - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Adolf_Eugen_Fick - Type: item - URIElement: http://xmlns.com/foaf/0.1/name - Type: item - LiteralElement: Adolf Eugen Fick - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Al_Lowe - Type: item - URIElement: http://xmlns.com/foaf/0.1/givenname - Type: item - LiteralElement: Al - Language: de
# INFO:hercules_sync.triplestore.wikibase_adapter:Create triple: URIElement: http://dbpedia.org/resource/Abraham_Jennison - Type: item - URIElement: http://xmlns.com/foaf/0.1/surname - Type: item - LiteralElement: Jennison - Language: de

# %% [markdown]
# As we can see above...

# %% [markdown]
# ## Batch vs Basic operations

# %% [markdown]
# As have seen in the previous section, the writing of triples to Wikibase is the main bottleneck of the system. In order to alleviate this problem, the 'optimize_ops' function is provided to convert a list of BasicOperations into BatchOperations.
#
# With this optimization the system will try to perform less writting operations, using instead the 'update' methods provided by WikidataIntegrator. In this section we are going to compare the performance using the basic operations against the 'optimized' version. First of all, we are going to define the functions needed to execute both types of synchronization:

# %%
def _synchronize(source_content, target_content, synchronizer, adapter, ops_callback):
    gitfile = GitFile(None, source_content, target_content)
    ops = ops_callback(gitfile)
    for op in ops:
        res = op.execute(adapter)
        if not res.successful:
            print(f"Error synchronizing triple: {res.message}")

def execute_basic_synchronization(source_content, target_content, synchronizer, adapter):
    ops_callback = lambda f: synchronizer.synchronize(f)
    return _synchronize(source_content, target_content, synchronizer, adapter, ops_callback)
    
def execute_batch_synchronization(source_content, target_content, synchronizer, adapter):
    ops_callback = lambda f: optimize_ops(synchronizer.synchronize(f))
    return _synchronize(source_content, target_content, synchronizer, adapter, ops_callback)

# %% [markdown]
# The first auxiliary function, '\_synchronize', is very similar to the synchronization function defined previously to profile the preview dataset. However, in this case we are receiving an additional callback to obtain the list of operations from the file.
#
# After that we define two more functions. The first one corresponds to the basic approach used so far, where the operations are obtained directly from our OntologySynchronizer instance. The second function will additionally call the _optimize\_ops_ function on the operations to optimize them.
